# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_excel("E:\hrData.xlsx")
gd=df.groupby('Job Role')['Employee Number'].sum()
print(gd)
gd.plot(kind='bar')
# Out:
# Job Role
# Healthcare Representative    140797
# Human Resources               64289
# Laboratory Technician        258793
# Manager                       96655
# Manufacturing Director       144820
# Research Director             79183
# Research Scientist           293018
# Sales Executive              342656
# Sales Representative          86341
# Name: Employee Number, dtype: int64
# <Axes: xlabel='Job Role'>

# %%
sd=df.groupby('Gender')['Employee Number'].sum()
print(sd)
sd.plot(kind='bar')
# Out:
# Gender
# Female    592845
# Male      913707
# Name: Employee Number, dtype: int64
# <Axes: xlabel='Gender'>

# %%
sf=df.groupby('Department')['Employee Number'].sum()
print(sf)
sf.plot(kind='bar')
# Out:
# Department
# HR        75932
# R&D      967250
# Sales    463370
# Name: Employee Number, dtype: int64
# <Axes: xlabel='Department'>
